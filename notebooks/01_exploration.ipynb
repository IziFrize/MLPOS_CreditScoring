# %% [markdown]
# # 01 - Exploration
# Chargement des CSV, schemas, valeurs manquantes, distribution de la target et controles de jointure.

# %%
import sys
sys.path.append('../')
from src.config import RAW_DIR
from src.preprocessing import load_data
data = load_data(RAW_DIR)
{k: v.shape for k, v in data.items()}

# %%
trainperf = data['trainperf']
trainperf['good_bad_flag'].value_counts(normalize=True)
