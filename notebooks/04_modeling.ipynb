# %% [markdown]
# # 04 - Modeling
# Le notebook lance le script d'entrainement puis lit la comparaison des modeles.

# %%
import sys
sys.path.append('../')
from src.train import main
main()

# %%
import pandas as pd
pd.read_csv('../data/processed/model_comparison.csv')
