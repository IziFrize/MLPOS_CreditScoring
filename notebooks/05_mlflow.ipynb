# %% [markdown]
# # 05 - MLflow
# Les runs sont logges par `src/train.py`. Lancer ensuite `mlflow ui --host 0.0.0.0 --port 5000`.

# %%
import pandas as pd
pd.read_csv('../data/processed/model_comparison.csv')
