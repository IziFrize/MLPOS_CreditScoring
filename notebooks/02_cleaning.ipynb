# %% [markdown]
# # 02 - Cleaning
# Application des fonctions de nettoyage reproductibles.

# %%
import sys
sys.path.append('../')
from src.config import RAW_DIR
from src.preprocessing import load_data, clean_perf, clean_demographics, clean_prevloans
data = load_data(RAW_DIR)
clean_perf(data['trainperf']).head()

# %%
clean_demographics(data['traindemographics']).head()

# %%
clean_prevloans(data['trainprevloans']).head()
